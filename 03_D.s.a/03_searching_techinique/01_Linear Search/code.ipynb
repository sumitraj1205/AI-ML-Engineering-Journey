# %%
def linear_search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i

    return -1


arr = [10, 25, 7, 18, 30]
x = 18

result = linear_search(arr, x)

print(result)
