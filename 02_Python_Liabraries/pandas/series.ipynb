# %%
#index and labels
import pandas as pd
a = pd.Series([20,23,21,22],index = ["sumit","kunal","rohan","shubham"])
print(a)
print(a["sumit"])
print(a[2])
print(a.index)
# Out:
# sumit      20
# kunal      23
# rohan      21
# shubham    22
# dtype: int64
# 20
# 21
# Index(['sumit', 'kunal', 'rohan', 'shubham'], dtype='object')
# C:\Users\sumit\AppData\Local\Temp\ipykernel_16664\3645244628.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(a[2])

# %%
#vectorisation
b = pd.Series([1,2,3,4,5])
c = pd.Series([10,20,30,40,50])
print(b+c)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
d = b.drop([0])
print(d)
# Out:
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
