# %%
#tranforming data
import pandas as pd
a = pd.read_csv("raw_data.csv")
b = a.copy()

# %%
b = b.drop_duplicates()
b = b.fillna(0)
b = b.sort_values("income")
b = b.reset_index(drop = True)

# %%
b.to_csv("transformed_data.csv")
