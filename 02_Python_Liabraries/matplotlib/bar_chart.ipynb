# %%
import matplotlib.pyplot as plt
movies = ["The Dark Knight", "The Hurt Locker", "The King's Speech", "The Artist", "Argo"]

years = [2008, 2009, 2010, 2011, 2012]

oscar_revenue = [1005, 170, 427, 133, 232]
plt.bar(years,oscar_revenue)
plt.xlabel("years")
plt.ylabel("earnings in $")
# Out:
# Text(0, 0.5, 'earnings in $')

# %%
movies = ["The Dark Knight", "The Hurt Locker", "The King's Speech", "The Artist", "Argo"]

years = [2008, 2009, 2010, 2011, 2012]

oscar_revenue = [1005, 170, 427, 133, 232]
plt.bar(years,oscar_revenue)
plt.xlabel("years")
plt.ylabel("earnings in $")
plt.ylim(0,max(oscar_revenue) + 100)
for i in range(len(years)):
    plt.text(years[i],oscar_revenue[i] + 10,movies[i],ha = "center")

# %%
import numpy as np
movies = ["The Dark Knight", "The Hurt Locker", "The King's Speech", "The Artist", "Argo"]

years = [2008, 2009, 2010, 2011, 2012]

oscar_revenue = [1005, 170, 427, 133, 232]

nonoscar_revenue = [265, 70, 127, 113, 32]
x = np.arange(len(years))
width = 0.4
plt.bar(x-width/2,oscar_revenue,width,label = "oscar movies")
plt.bar(x+width/2,nonoscar_revenue,width,label = "nonoscar movies")
plt.xlabel("years")
plt.ylabel("earnings in $")
plt.title("oscar vs non oscar movies")
plt.legend()

# %%
movies = ["The Dark Knight", "The Hurt Locker", "The King's Speech", "The Artist", "Argo"]

years = [2008, 2009, 2010, 2011, 2012]

oscar_revenue = [1005, 170, 427, 133, 232]
plt.barh(movies,oscar_revenue)
plt.ylabel("movies")
plt.xlabel("earnings in $")
# Out:
# Text(0.5, 0, 'earnings in $')
