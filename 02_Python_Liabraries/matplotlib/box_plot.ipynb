# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
a = np.random.normal(70,10,100)
b = np.random.normal(50,10,100)
plt.boxplot([a,b],tick_labels = ["1st marks","2nd marks"])
plt.show()

# %%
plt.boxplot(a,vert = False,showmeans = True,whis = 2.0)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24a78a49a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24a78a49d10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24a78a49950>],
#  'medians': [<matplotlib.lines.Line2D at 0x24a78a49f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24a78a4a210>],
#  'means': [<matplotlib.lines.Line2D at 0x24a78a4a0d0>]}
